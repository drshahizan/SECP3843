# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/SECP3843/blob/main/submission/Mincridible/question4%20/Question4_AA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (648 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.9/648.9 kB 31.5 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 25.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.4.0

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb+srv://mincridible:minzpro1@min.tan7fdn.mongodb.net/')
db = client['Companies']
collection = db['CompaniesMeta']

# %%
import pandas as pd

data = list(collection.find())

# Convert the data into a DataFrame
df = pd.DataFrame(data)
df
# Out:
#                            _id                              name    permalink  \
# 0     52cdef7c4bab8bd675297d8a                          Wetpaint         abc2
# 1     52cdef7c4bab8bd675297d8f                         Omnidrive    omnidrive
# 2     52cdef7c4bab8bd675297da0                          Babelgum     babelgum
# 3     52cdef7c4bab8bd675297d98                           Slacker      slacker
# 4     52cdef7c4bab8bd675297d97                            Scribd       scribd
# ...                        ...                               ...          ...
# 9496  52cdef7f4bab8bd67529c6f8                       goBookmaker  gobookmaker
# 9497  52cdef7f4bab8bd67529c6f7                        AfterLogic   afterlogic
# 9498  52cdef7f4bab8bd67529c6da                       Xray Imatek  xray-imatek
# 9499  52cdef7f4bab8bd67529c6d8                          NextLabs     nextlabs
# 9500  649974e3102149c5be05d049  Ahmad Muhaimin Bin Ahmad Hambali          NaN
#
#                                      crunchbase_url  \
# 0        http://www.crunchbase.com/company/wetpaint
# 1       http://www.crunchbase.com/company/omnidrive
# 2        http://www.crunchbase.com/company/babelgum
# 3         http://www.crunchbase.com/company/slacker
# 4          http://www.crunchbase.com/company/scribd
# ...                                             ...
# 9496  http://www.crunchbase.com/company/gobookmaker
# 9497   http://www.crunchbase.com/company/afterlogic
# 9498  http://www.crunchbase.com/company/xray-imatek
# 9499     http://www.crunchbase.com/company/nextlabs
# 9500                                            NaN
#
#                     homepage_url                       blog_url  \
# 0        http://wetpaint-inc.com    http://digitalquarters.net/
# 1       http://www.omnidrive.com  http://www.omnidrive.com/blog
# 2            http://babelgum.com       http://babelgum.com/blog
# 3         http://www.slacker.com
# 4              http://scribd.com        http://blog.scribd.com/
# ...                          ...                            ...
# 9496  http://www.gobookmaker.com    http://blog.gobookmaker.com
# 9497   http://www.afterlogic.com
# 9498  http://www.xray-imatek.com
# 9499     http://www.nextlabs.com  http://nextlabs.wordpress.com
# 9500                         NaN                            NaN
#
#                               blog_feed_url twitter_username    category_code  \
# 0          http://digitalquarters.net/feed/  BachelrWetpaint              web
# 1     http://feeds.feedburner.com/omnidrive         Nomadesk  network_hosting
# 2      http://feeds.feedburner.com/Babelgum         Babelgum      games_video
# 3                                               SlackerRadio            music
# 4              http://blog.scribd.com/feed/           scribd             news
# ...                                     ...              ...              ...
# 9496                                             gobookmaker              web
# 9497                                              afterlogic         software
# 9498                                                                  biotech
# 9499                                                nextlabs       enterprise
# 9500                                    NaN              NaN              NaN
#
#       number_of_employees  ...  \
# 0                    47.0  ...
# 1                     NaN  ...
# 2                     NaN  ...
# 3                     NaN  ...
# 4                    50.0  ...
# ...                   ...  ...
# 9496                  NaN  ...
# 9497                  NaN  ...
# 9498                  NaN  ...
# 9499                100.0  ...
# 9500                  NaN  ...
#
#                                             screenshots  \
# 0     [{'available_sizes': [[[150, 86], 'assets/imag...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4     [{'available_sizes': [[[150, 72], 'assets/imag...
# ...                                                 ...
# 9496  [{'available_sizes': [[[150, 80], 'assets/imag...
# 9497  [{'available_sizes': [[[150, 137], 'assets/ima...
# 9498  [{'available_sizes': [[[150, 117], 'assets/ima...
# 9499                                                 []
# 9500                                                NaN
#
#                                          external_links  partners  \
# 0     [{'external_url': 'http://www.geekwire.com/201...        []
# 1                                                    []        []
# 2                                                    []        []
# 3                                                    []        []
# 4     [{'external_url': 'http://www.online-tech-tips...        []
# ...                                                 ...       ...
# 9496                                                 []        []
# 9497                                                 []        []
# 9498                                                 []        []
# 9499                                                 []        []
# 9500                                                NaN       NaN
#
#       deadpooled_month deadpooled_day deadpooled_url   ipo   age  \
# 0                  NaN            NaN            NaN   NaN   NaN
# 1                  9.0           15.0                 None   NaN
# 2                  1.0            9.0                 None   NaN
# 3                  NaN            NaN           None  None   NaN
# 4                  NaN            NaN           None  None   NaN
# ...                ...            ...            ...   ...   ...
# 9496               NaN            NaN           None  None   NaN
# 9497               NaN            NaN           None  None   NaN
# 9498               NaN            NaN           None  None   NaN
# 9499               NaN            NaN           None  None   NaN
# 9500               NaN            NaN           None  None  27.0
#
#                            email   matricNO
# 0                            NaN        NaN
# 1                            NaN        NaN
# 2                            NaN        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
# ...                          ...        ...
# 9496                         NaN        NaN
# 9497                         NaN        NaN
# 9498                         NaN        NaN
# 9499                         NaN        NaN
# 9500  ahmadmuhaimin135@gmail.com  A20EC0006
#
# [9501 rows x 45 columns]

# %%
# Display the first few records of the DataFrame
print(df.head())
# Out:
#                         _id       name  permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint       abc2
# 1  52cdef7c4bab8bd675297d8f  Omnidrive  omnidrive
# 2  52cdef7c4bab8bd675297da0   Babelgum   babelgum
# 3  52cdef7c4bab8bd675297d98    Slacker    slacker
# 4  52cdef7c4bab8bd675297d97     Scribd     scribd
#
#                                 crunchbase_url              homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint   http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/omnidrive  http://www.omnidrive.com
# 2   http://www.crunchbase.com/company/babelgum       http://babelgum.com
# 3    http://www.crunchbase.com/company/slacker    http://www.slacker.com
# 4     http://www.crunchbase.com/company/scribd         http://scribd.com
#
#                         blog_url                          blog_feed_url  \
# 0    http://digitalquarters.net/       http://digitalquarters.net/feed/
# 1  http://www.omnidrive.com/blog  http://feeds.feedburner.com/omnidrive
# 2       http://babelgum.com/blog   http://feeds.feedburner.com/Babelgum
# 3
# 4        http://blog.scribd.com/           http://blog.scribd.com/feed/
#
#   twitter_username    category_code  number_of_employees  ...  \
# 0  BachelrWetpaint              web                 47.0  ...
# 1         Nomadesk  network_hosting                  NaN  ...
# 2         Babelgum      games_video                  NaN  ...
# 3     SlackerRadio            music                  NaN  ...
# 4           scribd             news                 50.0  ...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'available_sizes': [[[150, 72], 'assets/imag...
#
#                                       external_links  partners  \
# 0  [{'external_url': 'http://www.geekwire.com/201...        []
# 1                                                 []        []
# 2                                                 []        []
# 3                                                 []        []
# 4  [{'external_url': 'http://www.online-tech-tips...        []
#
#    deadpooled_month deadpooled_day deadpooled_url   ipo age email matricNO
# 0               NaN            NaN            NaN   NaN NaN   NaN      NaN
# 1               9.0           15.0                 None NaN   NaN      NaN
# 2               1.0            9.0                 None NaN   NaN      NaN
# 3               NaN            NaN           None  None NaN   NaN      NaN
# 4               NaN            NaN           None  None NaN   NaN      NaN
#
# [5 rows x 45 columns]

# %%
# Get information about the dataset, including column names, data types, and non-null values
print(df.info())

# Compute summary statistics for numerical columns
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9501 entries, 0 to 9500
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  9501 non-null   object
#  1   name                 9501 non-null   object
#  2   permalink            9500 non-null   object
#  3   crunchbase_url       9500 non-null   object
#  4   homepage_url         8523 non-null   object
#  5   blog_url             8520 non-null   object
#  6   blog_feed_url        8459 non-null   object
#  7   twitter_username     5714 non-null   object
#  8   category_code        8093 non-null   object
#  9   number_of_employees  4448 non-null   float64
#  10  founded_year         6651 non-null   float64
#  11  founded_month        3992 non-null   float64
#  12  founded_day          2782 non-null   float64
#  13  deadpooled_year      480 non-null    float64
#  14  tag_list             7440 non-null   object
#  15  alias_list           4477 non-null   object
#  16  email_address        8476 non-null   object
#  17  phone_number         8467 non-null   object
#  18  description          6206 non-null   object
#  19  created_at           9500 non-null   object
#  20  updated_at           9500 non-null   object
#  21  overview             8495 non-null   object
#  22  image                8143 non-null   object
#  23  products             9500 non-null   object
#  24  relationships        9500 non-null   object
#  25  competitions         9500 non-null   object
#  26  providerships        9500 non-null   object
#  27  total_money_raised   9500 non-null   object
#  28  funding_rounds       9500 non-null   object
#  29  investments          9500 non-null   object
#  30  acquisition          1326 non-null   object
#  31  acquisitions         9500 non-null   object
#  32  offices              9500 non-null   object
#  33  milestones           9500 non-null   object
#  34  video_embeds         9500 non-null   object
#  35  screenshots          9500 non-null   object
#  36  external_links       9500 non-null   object
#  37  partners             9500 non-null   object
#  38  deadpooled_month     400 non-null    float64
#  39  deadpooled_day       336 non-null    float64
#  40  deadpooled_url       553 non-null    object
#  41  ipo                  195 non-null    object
#  42  age                  1 non-null      float64
#  43  email                1 non-null      object
#  44  matricNO             1 non-null      object
# dtypes: float64(8), object(37)
# memory usage: 3.3+ MB
# None
#        number_of_employees  founded_year  founded_month  founded_day  \
# count          4448.000000   6651.000000    3992.000000  2782.000000
# mean           1042.943345   2002.421891       5.778056     8.846513
# std           13011.026017     13.450607       3.576748     9.453789
# min               0.000000   1800.000000       1.000000     1.000000
# 25%               4.000000   2001.000000       2.000000     1.000000
# 50%              10.000000   2006.000000       6.000000     4.000000
# 75%              32.000000   2007.000000       9.000000    15.000000
# max          388000.000000   2013.000000      12.000000    31.000000
#
#        deadpooled_year  deadpooled_month  deadpooled_day   age
# count       480.000000        400.000000      336.000000   1.0
# mean       2006.375000          6.282500       14.821429  27.0
# std          91.740222          3.428861        9.572237   NaN
# min           1.000000          1.000000        1.000000  27.0
# 25%        2009.000000          3.000000        5.000000  27.0
# 50%        2011.000000          6.000000       15.000000  27.0
# 75%        2012.000000         10.000000       23.250000  27.0
# max        2014.000000         12.000000       31.000000  27.0

# %%
# Check for missing values in each column
print(df.isnull().sum())
# Out:
# _id                       0
# name                      0
# permalink                 1
# crunchbase_url            1
# homepage_url            978
# blog_url                981
# blog_feed_url          1042
# twitter_username       3787
# category_code          1408
# number_of_employees    5053
# founded_year           2850
# founded_month          5509
# founded_day            6719
# deadpooled_year        9021
# tag_list               2061
# alias_list             5024
# email_address          1025
# phone_number           1034
# description            3295
# created_at                1
# updated_at                1
# overview               1006
# image                  1358
# products                  1
# relationships             1
# competitions              1
# providerships             1
# total_money_raised        1
# funding_rounds            1
# investments               1
# acquisition            8175
# acquisitions              1
# offices                   1
# milestones                1
# video_embeds              1
# screenshots               1
# external_links            1
# partners                  1
# deadpooled_month       9101
# deadpooled_day         9165
# deadpooled_url         8948
# ipo                    9306
# age                    9500
# email                  9500
# matricNO               9500
# dtype: int64

# %%
import numpy as np

# Splitting acquisitions Data
df['price_amount'] = df['acquisition'].apply(lambda x: x['price_amount'] if pd.notnull(x) else np.nan)
df['acquired_year'] = df['acquisition'].apply(lambda x: x['acquired_year'] if pd.notnull(x) else np.nan)

# Drop the original "acquisition" column
df.drop('acquisition', axis=1, inplace=True)

# %%
# Drop columns with a high percentage of missing values
df.drop(columns=['matricNO', 'email','age','ipo','blog_feed_url','twitter_username'], inplace=True)



print(df.isnull().sum())
# Out:
# _id                       0
# name                      0
# permalink                 1
# crunchbase_url            1
# homepage_url            978
# blog_url                981
# category_code          1408
# number_of_employees    5053
# founded_year           2850
# founded_month          5509
# founded_day            6719
# deadpooled_year        9021
# tag_list               2061
# alias_list             5024
# email_address          1025
# phone_number           1034
# description            3295
# created_at                1
# updated_at                1
# overview               1006
# image                  1358
# products                  1
# relationships             1
# competitions              1
# providerships             1
# total_money_raised        1
# funding_rounds            1
# investments               1
# acquisitions              1
# offices                   1
# milestones                1
# video_embeds              1
# screenshots               1
# external_links            1
# partners                  1
# deadpooled_month       9101
# deadpooled_day         9165
# deadpooled_url         8948
# price_amount           9078
# acquired_year          8184
# dtype: int64

# %%
# Impute missing values with mean
df['founded_year'].fillna(df['founded_year'].mean(), inplace=True)
df['founded_month'].fillna(df['founded_month'].mean(), inplace=True)
df['founded_day'].fillna(df['founded_day'].mean(), inplace=True)
df['deadpooled_year'].fillna(df['deadpooled_year'].mean(), inplace=True)
df['deadpooled_month'].fillna(df['deadpooled_month'].mean(), inplace=True)
df['deadpooled_day'].fillna(df['deadpooled_day'].mean(), inplace=True)
df['price_amount'].fillna(df['price_amount'].mean(), inplace=True)
df['acquired_year'].fillna(df['acquired_year'].mean(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# _id                       0
# name                      0
# permalink                 1
# crunchbase_url            1
# homepage_url            978
# blog_url                981
# category_code          1408
# number_of_employees    5053
# founded_year              0
# founded_month             0
# founded_day               0
# deadpooled_year           0
# tag_list               2061
# alias_list             5024
# email_address          1025
# phone_number           1034
# description            3295
# created_at                1
# updated_at                1
# overview               1006
# image                  1358
# products                  1
# relationships             1
# competitions              1
# providerships             1
# total_money_raised        1
# funding_rounds            1
# investments               1
# acquisitions              1
# offices                   1
# milestones                1
# video_embeds              1
# screenshots               1
# external_links            1
# partners                  1
# deadpooled_month          0
# deadpooled_day            0
# deadpooled_url         8948
# price_amount              0
# acquired_year             0
# dtype: int64

# %%
# Drop rows with missing values if they are a small portion of the dataset
df.dropna(axis=0, inplace=True)
print(df.isnull().sum())
# Out:
# _id                    0
# name                   0
# permalink              0
# crunchbase_url         0
# homepage_url           0
# blog_url               0
# category_code          0
# number_of_employees    0
# founded_year           0
# founded_month          0
# founded_day            0
# deadpooled_year        0
# tag_list               0
# alias_list             0
# email_address          0
# phone_number           0
# description            0
# created_at             0
# updated_at             0
# overview               0
# image                  0
# products               0
# relationships          0
# competitions           0
# providerships          0
# total_money_raised     0
# funding_rounds         0
# investments            0
# acquisitions           0
# offices                0
# milestones             0
# video_embeds           0
# screenshots            0
# external_links         0
# partners               0
# deadpooled_month       0
# deadpooled_day         0
# deadpooled_url         0
# price_amount           0
# acquired_year          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 7 to 9490
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  169 non-null    object
#  1   name                 169 non-null    object
#  2   permalink            169 non-null    object
#  3   crunchbase_url       169 non-null    object
#  4   homepage_url         169 non-null    object
#  5   blog_url             169 non-null    object
#  6   category_code        169 non-null    object
#  7   number_of_employees  169 non-null    float64
#  8   founded_year         169 non-null    float64
#  9   founded_month        169 non-null    float64
#  10  founded_day          169 non-null    float64
#  11  deadpooled_year      169 non-null    float64
#  12  tag_list             169 non-null    object
#  13  alias_list           169 non-null    object
#  14  email_address        169 non-null    object
#  15  phone_number         169 non-null    object
#  16  description          169 non-null    object
#  17  created_at           169 non-null    object
#  18  updated_at           169 non-null    object
#  19  overview             169 non-null    object
#  20  image                169 non-null    object
#  21  products             169 non-null    object
#  22  relationships        169 non-null    object
#  23  competitions         169 non-null    object
#  24  providerships        169 non-null    object
#  25  total_money_raised   169 non-null    object
#  26  funding_rounds       169 non-null    object
#  27  investments          169 non-null    object
#  28  acquisitions         169 non-null    object
#  29  offices              169 non-null    object
#  30  milestones           169 non-null    object
#  31  video_embeds         169 non-null    object
#  32  screenshots          169 non-null    object
#  33  external_links       169 non-null    object
#  34  partners             169 non-null    object
#  35  deadpooled_month     169 non-null    float64
#  36  deadpooled_day       169 non-null    float64
#  37  deadpooled_url       169 non-null    object
#  38  price_amount         169 non-null    float64
#  39  acquired_year        169 non-null    float64
# dtypes: float64(9), object(31)
# memory usage: 54.1+ KB

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Select the features based on your dataset
features = [
    'founded_year',
    'number_of_employees',
    'price_amount',
]

target = 'category_code'

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Instantiate the Gradient Boosting model with adjusted hyperparameters
gb_model = GradientBoostingClassifier(n_estimators=100, max_depth=3, random_state=42)

# Fit the model to the training data
gb_model.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = gb_model.predict(X_test)

# Evaluate the performance of the model
print(classification_report(y_test, y_pred))
# Out:
#                   precision    recall  f1-score   support
#
#        analytics       0.00      0.00      0.00         1
#        cleantech       0.00      0.00      0.00         2
#        ecommerce       0.00      0.00      0.00         1
#       enterprise       0.00      0.00      0.00         1
#          finance       0.00      0.00      0.00         1
#      games_video       0.25      0.25      0.25         4
#         hardware       0.00      0.00      0.00         0
#            legal       0.00      0.00      0.00         0
#           mobile       0.00      0.00      0.00         2
#            music       0.00      0.00      0.00         1
#  network_hosting       0.00      0.00      0.00         1
#            other       0.00      0.00      0.00         1
# public_relations       0.33      0.50      0.40         2
#           search       0.00      0.00      0.00         1
#         security       0.00      0.00      0.00         0
#           social       0.00      0.00      0.00         1
#         software       0.20      0.33      0.25         3
#              web       0.57      0.67      0.62        12
#
#         accuracy                           0.32        34
#        macro avg       0.08      0.10      0.08        34
#     weighted avg       0.27      0.32      0.29        34
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt

# Plot predicted values vs actual values
plt.figure(figsize=(16, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
