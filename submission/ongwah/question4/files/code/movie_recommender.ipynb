# %%
import pymongo
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %%
myclient = pymongo.MongoClient()
mydb = myclient["mflix"]
mycol = mydb["movies"]

mydoc = mycol.find()

# %%
df = pd.DataFrame(list(mydoc))
df.head()
# Out:
#                         _id  \
# 0  573a1390f29313caabcd4135
# 1  573a1390f29313caabcd42e8
# 2  573a1390f29313caabcd4323
# 3  573a1390f29313caabcd446f
# 4  573a1390f29313caabcd5501
#
#                                                 plot                   genres  \
# 0  Three men hammer on an anvil and pass a bottle...                  [Short]
# 1  A group of bandits stage a brazen train hold-u...         [Short, Western]
# 2  A young boy, opressed by his mother, goes on a...  [Short, Drama, Fantasy]
# 3  A greedy tycoon decides, on a whim, to corner ...           [Short, Drama]
# 4  A venal, spoiled stockbroker's wife impulsivel...                  [Drama]
#
#    runtime                                               cast  \
# 0      1.0                         [Charles Kayser, John Ott]
# 1     11.0  [A.C. Abadie, Gilbert M. 'Broncho Billy' Ander...
# 2     14.0  [Martin Fuller, Mrs. William Bechtel, Walter E...
# 3     14.0  [Frank Powell, Grace Henderson, James Kirkwood...
# 4     59.0  [Fannie Ward, Sessue Hayakawa, Jack Dean, Jame...
#
#    num_mflix_comments                       title  \
# 0                 1.0            Blacksmith Scene
# 1                 NaN     The Great Train Robbery
# 2                 2.0  The Land Beyond the Sunset
# 3                 1.0           A Corner in Wheat
# 4                 NaN                   The Cheat
#
#                                             fullplot countries   released  \
# 0  A stationary camera looks at a large anvil wit...     [USA] 1893-05-09
# 1  Among the earliest existing films in American ...     [USA] 1903-12-01
# 2  Thanks to the Fresh Air Fund, a slum child esc...     [USA] 1912-10-28
# 3  A greedy tycoon decides, on a whim, to corner ...     [USA] 1909-12-13
# 4  Edith Hardy uses charity funds for Wall Street...     [USA] 1915-12-13
#
#    ...                                           awards  \
# 0  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 1  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 2  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 4  ...  {'wins': 1, 'nominations': 0, 'text': '1 win.'}
#
#                      lastupdated  year  \
# 0  2015-08-26 00:03:50.133000000  1893
# 1  2015-08-13 00:27:59.177000000  1903
# 2  2015-08-29 00:27:45.437000000  1912
# 3  2015-08-13 00:46:30.660000000  1909
# 4  2015-08-31 00:41:20.670000000  1915
#
#                                          imdb   type  \
# 0     {'rating': 6.2, 'votes': 1189, 'id': 5}  movie
# 1   {'rating': 7.4, 'votes': 9847, 'id': 439}  movie
# 2    {'rating': 7.1, 'votes': 448, 'id': 488}  movie
# 3   {'rating': 6.6, 'votes': 1375, 'id': 832}  movie
# 4  {'rating': 6.5, 'votes': 1660, 'id': 5078}  movie
#
#                                             tomatoes  \
# 0  {'viewer': {'rating': 3, 'numReviews': 184, 'm...
# 1  {'viewer': {'rating': 3.7, 'numReviews': 2559,...
# 2  {'viewer': {'rating': 3.7, 'numReviews': 53, '...
# 3  {'viewer': {'rating': 3.6, 'numReviews': 109, ...
# 4  {'viewer': {'rating': 3.2, 'numReviews': 423, ...
#
#                                               poster  languages  \
# 0                                                NaN        NaN
# 1  https://m.media-amazon.com/images/M/MV5BMTU3Nj...  [English]
# 2  https://m.media-amazon.com/images/M/MV5BMTMzMD...  [English]
# 3                                                NaN  [English]
# 4  https://m.media-amazon.com/images/M/MV5BMjEzMj...  [English]
#
#                                              writers metacritic
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                 [Dorothy G. Shore]        NaN
# 3                                                NaN        NaN
# 4  [Hector Turnbull (scenario), Jeanie Macpherson...        NaN
#
# [5 rows x 22 columns]

# %%
df['fullplot'] = df['fullplot'].fillna('')

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['fullplot'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
titles = df['title']
indices = pd.Series(df.index, index=df['title'].str.lower())

# %%
def get_recommendations(title):
    idxlist = []
    title = title.lower()
    if title in indices.index:
        idx = indices[title]
        if(isinstance(idx, np.integer)):
            idxlist.append(idx)
            idx = idxlist
        for i in idx:
            sim_scores = list(enumerate(cosine_sim[i]))
            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
            sim_scores = sim_scores[1:21]
            movie_indices = [i[0] for i in sim_scores]
            print(titles.iloc[i], '(' + str(df.iloc[i]['year']) + ')', df.iloc[i]['countries'])
            print('---------------------------------------------------------------------')
            print(df.iloc[i]['fullplot'])
            print('---------------------------------------------------------------------')
            print()
            print('Recommendations:')
            tdf = titles.iloc[movie_indices].head(20)
            i=0
            for ind in tdf.index:
                i+=1
                print('• ' , tdf[ind])
            print()
            print()
    else:
        print("Movie not found")

# %%
get_recommendations('3 Idiots')
# Out:
# 3 Idiots (2009) ['India']
# ---------------------------------------------------------------------
# Farhan Qureshi and Raju Rastogi want to re-unite with their fellow collegian, Rancho, after faking a stroke aboard an Air India plane, and excusing himself from his wife - trouser less - respectively. Enroute, they encounter another student, Chatur Ramalingam, now a successful businessman, who reminds them of a bet they had undertaken 10 years ago. The trio, while recollecting hilarious antics, including their run-ins with the Dean of Delhi's Imperial College of Engineering, Viru Sahastrabudhe, race to locate Rancho, at his last known address - little knowing the secret that was kept from them all this time.
# ---------------------------------------------------------------------
#
# Recommendations:
# •  Dil
# •  Awaara
# •  Hide Away
# •  Enemy of the State
# •  Khaleja
# •  The Chumscrubber
# •  The Chumscrubber
# •  Polytechnique
# •  Halloween 4: The Return of Michael Myers
# •  Tian guo ni zi
# •  Dirty Rotten Scoundrels
# •  Delhi in a Day
# •  Phir Hera Pheri
# •  Delhi Safari
# •  Next Friday
# •  D-Day
# •  Kiss Me Again
# •  Nothing But the Best
# •  Student of the Year
# •  Ishq Vishk

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# The Dark Knight Rises (2012) ['USA', 'UK']
# ---------------------------------------------------------------------
# Despite his tarnished reputation after the events of The Dark Knight, in which he took the rap for Dent's crimes, Batman feels compelled to intervene to assist the city and its police force which is struggling to cope with Bane's plans to destroy the city.
# ---------------------------------------------------------------------
#
# Recommendations:
# •  Batman: The Dark Knight Returns, Part 2
# •  Batman Forever
# •  Batman
# •  Courageous
# •  The Dark Knight
# •  Batman Beyond: Return of the Joker
# •  Batman: Gotham Knight
# •  Torrente 2: Mission in Marbella
# •  The Sniper
# •  Batman Returns
# •  Batman: Mask of the Phantasm
# •  The Seventh Seal
# •  The War at Home
# •  Project A 2
# •  Something from Nothing: The Art of Rap
# •  Get Rich or Die Tryin'
# •  Europe '51
# •  CHiPs '99
# •  The Forgotten
# •  Crime Busters

# %%
get_recommendations('The Avengers')
