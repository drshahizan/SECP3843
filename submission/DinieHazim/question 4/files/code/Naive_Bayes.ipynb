# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/SECP3843/blob/main/submission/DinieHazim/question%204/files%20/code/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (648 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.9/648.9 kB 9.9 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 21.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.4.0

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from pymongo import MongoClient

# %%
# Set up MongoDB connection
client = MongoClient('mongodb://DinieHazim:diniehazim@ac-c4beezk-shard-00-00.nd5oq2m.mongodb.net:27017,ac-c4beezk-shard-00-01.nd5oq2m.mongodb.net:27017,ac-c4beezk-shard-00-02.nd5oq2m.mongodb.net:27017/?replicaSet=atlas-fcyv7c-shard-0&ssl=true&authSource=admin')
db = client['test']
collection = db['Stories']

# Retrieve data from MongoDB
data = list(collection.find())

# %%
df = pd.DataFrame(data)
df
# Out:
#                            _id  \
# 0     4ba267dc238d3ba3ca00001d
# 1     4ba267dc238d3ba3ca000036
# 2     4ba267dc238d3ba3ca000001
# 3     4ba267dc238d3ba3ca000033
# 4     4ba267dc238d3ba3ca000039
# ...                        ...
# 9837  4ba281d4238d3ba3ca0026e4
# 9838  4ba281d4238d3ba3ca0026e8
# 9839  4ba281d4238d3ba3ca0026fb
# 9840  4ba281d4238d3ba3ca002709
# 9841  4ba281d4238d3ba3ca00270b
#
#                                                    href  \
# 0     http://digg.com/microsoft/Windows_Phone_7_Seri...
# 1     http://digg.com/health/Need_Viagra_You_May_Be_...
# 2     http://digg.com/people/Jedi_believer_who_refus...
# 3     http://digg.com/general_sciences/Molecules_Cou...
# 4          http://digg.com/odd_stuff/Invisible_Hulk_GIF
# ...                                                 ...
# 9837  http://digg.com/nintendo/Nintendo_to_Greenpeac...
# 9838  http://digg.com/space/Do_rocks_from_Mars_bear_...
# 9839  http://digg.com/politics/Bird_plane_Collisions...
# 9840         http://digg.com/movies/A_Tribute_to_Gollum
# 9841  http://digg.com/business_finance/5_Reasons_Por...
#
#                                                   title  comments  \
# 0      Windows Phone 7 Series won't have copy and paste       138
# 1     Need Viagra? You May Be at Risk for Fatal Hear...        19
# 2     'Jedi' believer who refused to remove hood get...       153
# 3     Molecules Could Create Tiny Circuits on Comput...        11
# 4                              Invisible Hulk??!! [GIF]       266
# ...                                                 ...       ...
# 9837  Nintendo to Greenpeace: We do care about the e...        28
# 9838         Do rocks from Mars bear the signs of life?        31
# 9839  Bird-plane Collisions May Pass 10,000 for the ...        42
# 9840                                A Tribute to Gollum        37
# 9841                 5 Reasons Porn-for-Profit Is Dying       145
#
#                                               container         submit_date  \
# 0     {'name': 'Technology', 'short_name': 'technolo... 2010-03-16 21:47:36
# 1      {'name': 'Lifestyle', 'short_name': 'lifestyle'} 2010-03-16 05:22:46
# 2          {'name': 'Offbeat', 'short_name': 'offbeat'} 2010-03-16 20:36:41
# 3          {'name': 'Science', 'short_name': 'science'} 2010-03-16 20:42:20
# 4          {'name': 'Offbeat', 'short_name': 'offbeat'} 2010-03-16 22:49:28
# ...                                                 ...                 ...
# 9837         {'name': 'Gaming', 'short_name': 'gaming'} 2010-01-12 11:04:00
# 9838       {'name': 'Science', 'short_name': 'science'} 2010-01-11 18:26:35
# 9839  {'name': 'World & Business', 'short_name': 'wo... 2010-01-12 09:36:53
# 9840  {'name': 'Entertainment', 'short_name': 'enter... 2010-01-11 17:01:13
# 9841  {'name': 'World & Business', 'short_name': 'wo... 2010-01-11 22:58:38
#
#                                                   topic        promote_date  \
# 0      {'name': 'Microsoft', 'short_name': 'microsoft'} 2010-03-17 11:30:58
# 1            {'name': 'Health', 'short_name': 'health'} 2010-03-17 05:50:02
# 2            {'name': 'People', 'short_name': 'people'} 2010-03-18 12:39:24
# 3     {'name': 'General Sciences', 'short_name': 'ge... 2010-03-17 06:20:03
# 4      {'name': 'Odd Stuff', 'short_name': 'odd_stuff'} 2010-03-17 05:30:02
# ...                                                 ...                 ...
# 9837     {'name': 'Nintendo', 'short_name': 'nintendo'} 2010-01-12 20:10:04
# 9838           {'name': 'Space', 'short_name': 'space'} 2010-01-12 19:30:07
# 9839  {'name': 'Political News', 'short_name': 'poli... 2010-01-12 17:40:00
# 9840         {'name': 'Movies', 'short_name': 'movies'} 2010-01-12 15:10:03
# 9841  {'name': 'Business & Finance', 'short_name': '... 2010-01-12 14:40:40
#
#             id   media  ...  \
# 0     19971395    news  ...
# 1     19953258    news  ...
# 2     19970068    news  ...
# 3     19970164    news  ...
# 4     19972468  images  ...
# ...        ...     ...  ...
# 9837  18441685    news  ...
# 9838  18424467    news  ...
# 9839  18440179    news  ...
# 9840  18422373    news  ...
# 9841  18430014    news  ...
#
#                                                    link  \
# 0     http://www.engadget.com/2010/03/16/windows-pho...
# 1     http://www.latimes.com/news/nationworld/nation...
# 2     http://www.dailymail.co.uk/news/article-125836...
# 3             http://www.physorg.com/news187968679.html
# 4                          http://i.imgur.com/qthck.gif
# ...                                                 ...
# 9837  http://www.joystiq.com/2010/01/12/nintendo-to-...
# 9838  http://cosmiclog.msnbc.msn.com/archive/2010/01...
# 9839  http://news.yahoo.com/s/ap/20100112/ap_on_bi_g...
# 9840  http://media.gunaxin.com/a-tribute-to-gollum/3...
# 9841  http://www.thedailybeast.com/blogs-and-stories...
#
#                                                    user   status  \
# 0     {'name': 'jstennis1591', 'registered': 1142994...  popular
# 1     {'name': 'weirdralph', 'registered': 118248481...  popular
# 2     {'name': 'babychen', 'registered': 1141570067,...  popular
# 3     {'name': 'legofanboy', 'registered': 124837043...  popular
# 4     {'name': 'pavelstropov', 'registered': 1247677...  popular
# ...                                                 ...      ...
# 9837  {'name': 'kevinlouis', 'registered': 122243001...  popular
# 9838  {'name': 'ScottMcIntyre', 'registered': 121517...  popular
# 9839  {'name': 'oteque', 'registered': 1236308780, '...  popular
# 9840  {'name': 'chris1234', 'registered': 1175061300...  popular
# 9841  {'name': 'mklopez', 'registered': 1121877948, ...  popular
#
#                                                shorturl submit_year  \
# 0     [{'short_url': 'http://digg.com/d31LnTH', 'vie...        2010
# 1     [{'short_url': 'http://digg.com/d31Likk', 'vie...        2010
# 2     [{'short_url': 'http://digg.com/d31Ln7s', 'vie...        2010
# 3     [{'short_url': 'http://digg.com/d31Ln9Q', 'vie...        2010
# 4     [{'short_url': 'http://digg.com/d31Lnka', 'vie...        2010
# ...                                                 ...         ...
# 9837  [{'short_url': 'http://digg.com/d31FNWX', 'vie...        2010
# 9838  [{'short_url': 'http://digg.com/d31FJ2p', 'vie...        2010
# 9839  [{'short_url': 'http://digg.com/d31FN8F', 'vie...        2010
# 9840  [{'short_url': 'http://digg.com/d31FIV3', 'vie...        2010
# 9841  [{'short_url': 'http://digg.com/d31FKUI', 'vie...        2010
#
#      promote_year                                          thumbnail  \
# 0            2010                                                NaN
# 1            2010  {'originalheight': 143, 'originalwidth': 139, ...
# 2            2010                                                NaN
# 3            2010  {'originalheight': 260, 'originalwidth': 260, ...
# 4            2010                                                NaN
# ...           ...                                                ...
# 9837         2010  {'originalheight': 269, 'originalwidth': 580, ...
# 9838         2010  {'originalheight': 295, 'originalwidth': 466, ...
# 9839         2010  {'originalheight': 307, 'originalwidth': 409, ...
# 9840         2010                                                NaN
# 9841         2010  {'originalheight': 185, 'originalwidth': 200, ...
#
#       inaccurate takedowndays  takedownuri
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# 3            NaN          NaN          NaN
# 4            NaN          NaN          NaN
# ...          ...          ...          ...
# 9837         NaN          NaN          NaN
# 9838         NaN          NaN          NaN
# 9839         NaN          NaN          NaN
# 9840         NaN          NaN          NaN
# 9841         NaN          NaN          NaN
#
# [9842 rows x 22 columns]

# %%
df.shape
# Out:
# (9842, 22)

# %%
df.isna().sum()
# Out:
# _id                0
# href               0
# title              0
# comments           0
# container          0
# submit_date        0
# topic              0
# promote_date       0
# id                 0
# media              0
# diggs              0
# description        0
# link               0
# user               0
# status             0
# shorturl           0
# submit_year        0
# promote_year       0
# thumbnail       3176
# inaccurate      9837
# takedowndays    9841
# takedownuri     9841
# dtype: int64

# %%
df["thumbnail"].fillna("NaN", inplace = True)
df["inaccurate"].fillna("NaN", inplace = True)
df["takedowndays"].fillna("NaN", inplace = True)
df["takedownuri"].fillna("NaN", inplace = True)

# %%
df.isna().sum()
# Out:
# _id             0
# href            0
# title           0
# comments        0
# container       0
# submit_date     0
# topic           0
# promote_date    0
# id              0
# media           0
# diggs           0
# description     0
# link            0
# user            0
# status          0
# shorturl        0
# submit_year     0
# promote_year    0
# thumbnail       0
# inaccurate      0
# takedowndays    0
# takedownuri     0
# dtype: int64

# %%
descriptions = []
topic_names = []

for story in data:
    description = story['description']
    topic_name = story['topic']['name']
    descriptions.append(description)
    topic_names.append(topic_name)

# %%
X_train, X_test, y_train, y_test = train_test_split(descriptions, topic_names, test_size=0.2, random_state=42)

vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

nb_classifier = MultinomialNB()

nb_classifier.fit(X_train_vec, y_train)

y_pred = nb_classifier.predict(X_test_vec)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.45606907059421026

# %%
new_text = 'Kevin Hart'
new_text_vec = vectorizer.transform([new_text])
predicted_topic = nb_classifier.predict(new_text_vec)
print("Predicted Topic:", predicted_topic)
# Out:
# Predicted Topic: ['Movies']

# %%
new_text = 'Jocelyn Chia'
new_text_vec = vectorizer.transform([new_text])
predicted_topic = nb_classifier.predict(new_text_vec)
print("Predicted Topic:", predicted_topic)
# Out:
# Predicted Topic: ['World News']
