# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/SECP3843/blob/main/submission/myzanazifah/question4/files/code/q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.3.0)

# %%
import pymongo
import pandas as pd
import numpy as np

# %%
# Connect to MongoDB server
client = pymongo.MongoClient("mongodb+srv://mnazifa:myza0701@cluster0.k5mjpna.mongodb.net/test")

# Access the database and collection
db = client["stories"]
collection = db["col_stories"]

# Retrieve data from the collection
data = list(collection.find())

# Convert data to a dataframe
df = pd.DataFrame(data)
df
# Out:
#                            _id  \
# 0     4ba267dc238d3ba3ca000001
# 1     4ba267dc238d3ba3ca000003
# 2     4ba267dc238d3ba3ca000004
# 3     4ba267dc238d3ba3ca000005
# 4     4ba267dc238d3ba3ca000006
# ...                        ...
# 9837  4ba281d4238d3ba3ca00270c
# 9838  4ba281d4238d3ba3ca00270d
# 9839  4ba281d4238d3ba3ca00270e
# 9840  4ba281d4238d3ba3ca00270f
# 9841  4ba281d4238d3ba3ca002710
#
#                                                    href  \
# 0     http://digg.com/people/Jedi_believer_who_refus...
# 1     http://digg.com/odd_stuff/Man_Assaulted_Female...
# 2     http://digg.com/pets_animals/Can_Killer_Whales...
# 3     http://digg.com/general_sciences/Study_Today_s...
# 4     http://digg.com/travel_places/11_Amazing_Treeh...
# ...                                                 ...
# 9837  http://digg.com/television/The_Simpsons_Celebr...
# 9838  http://digg.com/general_sciences/Classified_Re...
# 9839  http://digg.com/politics/Joe_Biden_Criticized_...
# 9840  http://digg.com/world_news/Leading_climate_sci...
# 9841  http://digg.com/people/Strongest_Man_in_the_Wo...
#
#                                                   title  comments  \
# 0     'Jedi' believer who refused to remove hood get...       153
# 1     Man Assaulted Female Police Officer With His P...        93
# 2            Can Killer Whales decide to kill a person?        58
# 3     Study: Today's youth aren't ego-driven slacker...        79
# 4           11 Amazing Treehouses from Around the World        15
# ...                                                 ...       ...
# 9837  "The Simpsons" Celebrates 20th Anniversary wit...        30
# 9838  Classified Recordings of First Fusion Bomb Tes...        20
# 9839  Joe Biden Criticized For Appearing In Hennessy...        45
# 9840  Leading climate scientist attacks use of his r...       208
# 9841          ‘Strongest Man in the World’ dies at 104        291
#
#                                               container  submit_date  \
# 0          {'name': 'Offbeat', 'short_name': 'offbeat'}   1268771801
# 1          {'name': 'Offbeat', 'short_name': 'offbeat'}   1268755030
# 2          {'name': 'Offbeat', 'short_name': 'offbeat'}   1268759982
# 3          {'name': 'Science', 'short_name': 'science'}   1268725903
# 4      {'name': 'Lifestyle', 'short_name': 'lifestyle'}   1268772915
# ...                                                 ...          ...
# 9837  {'name': 'Entertainment', 'short_name': 'enter...   1263229534
# 9838       {'name': 'Science', 'short_name': 'science'}   1263242162
# 9839  {'name': 'World & Business', 'short_name': 'wo...   1263262913
# 9840  {'name': 'World & Business', 'short_name': 'wo...   1263231337
# 9841       {'name': 'Offbeat', 'short_name': 'offbeat'}   1263303148
#
#                                                   topic  promote_date  \
# 0            {'name': 'People', 'short_name': 'people'}    1268915964
# 1      {'name': 'Odd Stuff', 'short_name': 'odd_stuff'}    1268903731
# 2     {'name': 'Pets & Animals', 'short_name': 'pets...    1268892002
# 3     {'name': 'General Sciences', 'short_name': 'ge...    1268866803
# 4     {'name': 'Travel & Places', 'short_name': 'tra...    1268858405
# ...                                                 ...           ...
# 9837  {'name': 'Television', 'short_name': 'televisi...    1263307202
# 9838  {'name': 'General Sciences', 'short_name': 'ge...    1263306603
# 9839  {'name': 'Political News', 'short_name': 'poli...    1263306493
# 9840  {'name': 'World News', 'short_name': 'world_ne...    1263306315
# 9841         {'name': 'People', 'short_name': 'people'}    1263305836
#
#             id   media  diggs  \
# 0     19970068    news    404
# 1     19963997    news    262
# 2     19965986    news    293
# 3     19955283    news    493
# 4     19970430    news    375
# ...        ...     ...    ...
# 9837  18422480    news    276
# 9838  18427306    news    364
# 9839  18433089  videos    463
# 9840  18423241    news    278
# 9841  18444205    news   1581
#
#                                             description  \
# 0     Chris Jarvis is a member of the International ...
# 1     A 28-year-old man who assaulted a female polic...
# 2     Researchers have yet to find evidence that an ...
# 3     Today's youth are generally not the self-cente...
# 4     Treehouses bring us closer to nature, and appe...
# ...                                                 ...
# 9837  Fox celebrated the 20th anniversary of The Sim...
# 9838  The long-distance scientific recordings of the...
# 9839  Citing White House Pressure, Hennessy pulled t...
# 9840  Mojib Latif denies his research supports theor...
# 9841  Joe Rollino, a famed strongman who once lifted...
#
#                                                    link  \
# 0     http://www.dailymail.co.uk/news/article-125836...
# 1     http://news.bbc.co.uk/1/hi/scotland/north_east...
# 2     http://articles.orlandosentinel.com/2010-03-07...
# 3     http://www.brainmysteries.com/research/Study_T...
# 4     http://www.thedailygreen.com/green-homes/lates...
# ...                                                 ...
# 9837  http://mashable.com/2010/01/11/the-simpsons-tu...
# 9838  http://www.wired.com/wiredscience/2010/01/firs...
# 9839  http://www.theonion.com/content/video/biden_cr...
# 9840  http://www.guardian.co.uk/environment/2010/jan...
# 9841  http://www.msnbc.msn.com/id/34818457/ns/us_new...
#
#                                                    user   status  \
# 0     {'name': 'babychen', 'registered': 1141570067,...  popular
# 1     {'name': 'LyndonFM', 'registered': 1192555553,...  popular
# 2     {'name': 'whiteblackninja', 'registered': 1245...  popular
# 3     {'name': 'lekahe', 'registered': 1187263066, '...  popular
# 4     {'name': 'smurfz', 'registered': 1147707877, '...  popular
# ...                                                 ...      ...
# 9837  {'name': 'wbrns', 'registered': 1223585943, 'f...  popular
# 9838  {'name': 'mikeinto', 'registered': 1179075710,...  popular
# 9839  {'name': 'HeDiggMe', 'registered': 1189026689,...  popular
# 9840  {'name': 'Andrewt522', 'registered': 120698249...  popular
# 9841  {'name': 'mmaine', 'registered': 1225403319, '...  popular
#
#                                                shorturl  \
# 0     [{'short_url': 'http://digg.com/d31Ln7s', 'vie...
# 1     [{'short_url': 'http://digg.com/d31LlXx', 'vie...
# 2     [{'short_url': 'http://digg.com/d31Lm42', 'vie...
# 3     [{'short_url': 'http://digg.com/d31LjHP', 'vie...
# 4     [{'short_url': 'http://digg.com/d31LnDi', 'vie...
# ...                                                 ...
# 9837  [{'short_url': 'http://digg.com/d31FIWm', 'vie...
# 9838  [{'short_url': 'http://digg.com/d31FJmc', 'vie...
# 9839  [{'short_url': 'http://digg.com/d31FLHt', 'vie...
# 9840  [{'short_url': 'http://digg.com/d31FIj3', 'vie...
# 9841  [{'short_url': 'http://digg.com/d31FOBB', 'vie...
#
#                                               thumbnail  inaccurate  \
# 0                                                   NaN         NaN
# 1     {'originalheight': 170, 'originalwidth': 226, ...         NaN
# 2     {'originalheight': 476, 'originalwidth': 768, ...         NaN
# 3     {'originalheight': 232, 'originalwidth': 350, ...         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 9837                                                NaN         NaN
# 9838  {'originalheight': 439, 'originalwidth': 660, ...         NaN
# 9839  {'originalheight': 199, 'originalwidth': 298, ...         NaN
# 9840  {'originalheight': 84, 'originalwidth': 140, '...         NaN
# 9841  {'originalheight': 273, 'originalwidth': 290, ...         NaN
#
#       takedowndays takedownuri
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 9837           NaN         NaN
# 9838           NaN         NaN
# 9839           NaN         NaN
# 9840           NaN         NaN
# 9841           NaN         NaN
#
# [9842 rows x 20 columns]

# %%
df.shape
# Out:
# (9842, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9842 entries, 0 to 9841
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           9842 non-null   object
#  1   href          9842 non-null   object
#  2   title         9842 non-null   object
#  3   comments      9842 non-null   int64
#  4   container     9842 non-null   object
#  5   submit_date   9842 non-null   int64
#  6   topic         9842 non-null   object
#  7   promote_date  9842 non-null   int64
#  8   id            9842 non-null   object
#  9   media         9842 non-null   object
#  10  diggs         9842 non-null   int64
#  11  description   9842 non-null   object
#  12  link          9842 non-null   object
#  13  user          9842 non-null   object
#  14  status        9842 non-null   object
#  15  shorturl      9842 non-null   object
#  16  thumbnail     6666 non-null   object
#  17  inaccurate    5 non-null      float64
#  18  takedowndays  1 non-null      float64
#  19  takedownuri   1 non-null      object
# dtypes: float64(2), int64(4), object(14)
# memory usage: 1.5+ MB

# %%
df.isna().sum()
# Out:
# _id                0
# href               0
# title              0
# comments           0
# container          0
# submit_date        0
# topic              0
# promote_date       0
# id                 0
# media              0
# diggs              0
# description        0
# link               0
# user               0
# status             0
# shorturl           0
# thumbnail       3176
# inaccurate      9837
# takedowndays    9841
# takedownuri     9841
# dtype: int64

# %%
df["thumbnail"].fillna("NaN", inplace = True)
df["inaccurate"].fillna("NaN", inplace = True)
df["takedowndays"].fillna("NaN", inplace = True)
df["takedownuri"].fillna("NaN", inplace = True)

# %%
df.isna().sum()
# Out:
# _id             0
# href            0
# title           0
# comments        0
# container       0
# submit_date     0
# topic           0
# promote_date    0
# id              0
# media           0
# diggs           0
# description     0
# link            0
# user            0
# status          0
# shorturl        0
# thumbnail       0
# inaccurate      0
# takedowndays    0
# takedownuri     0
# dtype: int64

# %%
# Extract the relevant features for clustering
features = df[['comments', 'diggs']]
features
# Out:
#       comments  diggs
# 0          153    404
# 1           93    262
# 2           58    293
# 3           79    493
# 4           15    375
# ...        ...    ...
# 9837        30    276
# 9838        20    364
# 9839        45    463
# 9840       208    278
# 9841       291   1581
#
# [9842 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
scaled_features
# Out:
# array([[ 0.4517048 , -0.29615107],
#        [-0.06742175, -0.51677218],
#        [-0.37024557, -0.46860842],
#        ...,
#        [-0.48272299, -0.20448455],
#        [ 0.92757081, -0.49191347],
#        [ 1.64569587,  1.53251833]])

# %%
k_values = [2, 3, 4, 5, 6, 7, 8, 9, 10]

for k in k_values:
    kmeans = KMeans(n_clusters=k, init="random", random_state=42)
    kmeans.fit(scaled_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
cluster_labels = kmeans.labels_
cluster_labels
# Out:
# array([3, 2, 1, ..., 1, 3, 9], dtype=int32)

# %%
features['cluster_label'] = cluster_labels
features
# Out:
# <ipython-input-97-879422aefff3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['cluster_label'] = cluster_labels
#       comments  diggs  cluster_label
# 0          153    404              3
# 1           93    262              2
# 2           58    293              1
# 3           79    493              2
# 4           15    375              1
# ...        ...    ...            ...
# 9837        30    276              1
# 9838        20    364              1
# 9839        45    463              1
# 9840       208    278              3
# 9841       291   1581              9
#
# [9842 rows x 3 columns]

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.28889347,  1.0360694 ],
#        [-0.59468954, -0.44222098],
#        [-0.21317603, -0.1871023 ],
#        [ 0.49706038, -0.19596378],
#        [ 0.99031511,  2.7264543 ],
#        [ 2.5760253 ,  8.93076702],
#        [ 2.21779325,  4.4132793 ],
#        [ 6.44694054,  3.37648167],
#        [ 3.15932186,  1.22875576],
#        [ 1.69185396,  0.21321613]])

# %%
plt.scatter(features['comments'], features['diggs'], c=features['cluster_label'], cmap='viridis')
plt.xlabel('Number of Comments')
plt.ylabel('Number of Diggs')
plt.title('K-means Clustering')
plt.colorbar(label='Cluster')
plt.show()

# %%
range_of_k = range(2,15)

values = []
for k in range_of_k:
    kmeans = KMeans(n_clusters=k, init="random", random_state=42)
    kmeans.fit(scaled_features)
    values.append(kmeans.inertia_)

plt.plot(range_of_k, values, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('K-means Inertia')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt

range_of_k = range(2, 15)
silhouette_scores = []

for k in range_of_k:
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(scaled_features)
    silhouette_avg = silhouette_score(scaled_features, cluster_labels)
    silhouette_scores.append(silhouette_avg)


plt.plot(range_of_k, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Analysis')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
k = 2
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(scaled_features)


cluster_labels = kmeans.labels_
features['cluster_label'] = cluster_labels

# Visualize the clusters
plt.scatter(df['comments'], features['diggs'], c=features['cluster_label'], cmap='viridis')
plt.xlabel('Number of Comments')
plt.ylabel('Number of Diggs')
plt.title('K-means Clustering')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-102-7705f20b3dc8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['cluster_label'] = cluster_labels
